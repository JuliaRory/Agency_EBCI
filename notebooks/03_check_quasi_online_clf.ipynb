# %%
filenamme_original = 
data

# %%
filename = r"../data/tests/scores.hdf"
import h5py
with h5py.File(filename, "r") as h5f:
    scores_raw = h5f["scores_raw"][:]
    scores_dec = h5f["scores_dec"][:]

# %%
fig, ax= plt.subplots(3, 1, figsize=(15, 5))
ax[0].plot(scores_raw)
ax[1].plot(scores_dec)
ax[2].plot(data[:, -1])
